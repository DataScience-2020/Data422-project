# %% [markdown]
# ## Group Diary
#
# ### July 14th 2020 Sunny
#
# The wrangling group was established today. Our team members are  technical expert Jay (Jian Zhou), Linda (Zhu Jiaying), Christine (Chen Shi). Most of the time, we use the app "wechart" for discussion and small chat.
#
# ### July 19th 2020 Sunny
#
# Christine saw that there was an online classmate Waqas was looking for group number, it is hard for him to find group number, so we involved him in.
#
# ### July 22th 2020 Sunny
#
# First whole group numbers meeting, we are glad to meet each other and we are all easy going. It is a good and new family.
#
# ### July 23th 2020 Sunny
#
# Sarah has some questions about her Assignement 1, the challenge part, Jay helpt to solve it and showed her how to do it. Christine also shared some useful information.
#
# ### Augest 18th 2020 Sunny
#
# Christine Emailed the lecturers for asking wheter five numbers group is alright. No reply yet.
#
# ### September 9th 2020 Windy
#
# First formal Group project meeting, Jay attend by cell phone. Christine suggest to choose 1-2 topics, she suggest to do online store data scrap. No one objected, Jay said he also had some data related to stores, which could be used in the project.
#
# ### September 15th 2020 Sunny
#
# Christine and Jay met to discuss the data Jay mentioned before. After check, it cannot be used in the project, first it is clean dataframe, second the data cannot connect with the data we may scrap from NZ online stores in any demetion. (There is no price there, only transaction details, but online stores data only has price but no transation details).
#
# ### September 16th 2020 Sunny
#
# Waqas suggested to use Github as working flat. And he will give us a short tutorial about how to use Github. We also discuss the data rescourse can be used in this project. Someone suggest Kaggel, but it is too clean to be used. Christine shared the link can be used for searching online store information. Sarah successfully created the group project repo and invited all of us. Christine share the project_plan.
#
# ### September 17th 2020 Rainy Lab
#
# Waqas didn't attend the lab, we did recording for him. This lab brought a big adjustments to the entire project. Our topic online shopping was too easy which may not benefit the futher job.
#
# ### September 19th 2020 Rainy wechart
#
# Sarah shared her demo_APls.R in group.
#
#
# ### September 24th 2020 Rainy Lab
#
# This lab we rediscuss our group project topics again, the decision is each one of us has to work on one topic and have a try first. This will make sure we can survived to the end. Clearn data is not good for this course.
#
#
# ### September 24th 2020 windy Lab
#
# This lab we rediscuss our group project topics again, the decision is each one of us has to work on one topic and have a try first. This will make sure we can survived to the end. Clearn data is not good for this course. Waqas and Jay will work on movie data, Sarah will forcus on geograoh data and visualization, Linda want to work on coins. Christine was struggle with whether should change online shopping or not, she heard unless three groups had the same idea, she decided to change to Game data. We discuss a lot about the topics and how to organize them together to be sensible. Our strategy is to try the topic -- find the data scource -- try to generate some data -- if works, carry on (doesn't work, stop) -- collect the data information we can use -- find a direction can group all the topics.
#
#
# ### September 28th 2020 wechart
#
# Sarah and Jay help Waqas to solve the problem about saving response in a for loop.
#
#
#
# ### September 29th 2020 Email
# Christine and Sarah discussed about how to organize the topics and worked together to generate some information from IGDB. Sarah has got all the geograh tools done.
#
# Christine share the project story line to group all the topics.
# Christine found three Game data rescources, IGDB is the ideal one. The other two has some different issues, they will be listed as subtitude.
#
# ### Octorber 2nd 2020 wechart
#
# Waqas recommended a good websit which is about IMDb data analysis.
#
# ### Octorber 7nd 2020 wechart
#
# Waqas organized group project Github structure.
#
#
# ### Octorber 8th 2020 lab
#
# Sarah are doing on geo-data by querying with API and trying to visualize it on global map. The variables that I guess may be useful for team final dataframe are location variables, such as city name, longitude, altitude.
#
#
# Waqas and Jay have imdb data which has movie details along with actor’s / producers from which we are modelling/extracting the information of actors which took part in any movie during last x year and the movie generate xyz revenue...  from this we can make some predictions that the actor will be available and going to take part in X movie genre.
#
# Waqas suggests we can then match the gaming types with the movie genres and bring out the info that this specific actor can be used for the Gaming advertisement as he took part in a movie with a genre Action
#
# Jay helped Linda and Waqas with web scraping and automation process. Working on Twitter information extraction and plotting.
#
# Linda was working on crypocurrencies real time data from a website called CoinMarketCap. He suggests we can extract information including rank, coin's name, symbol, market cap, price, volumn etc. as a csv file. Then doing some analysis and plotting using R.
#
# Christine are doing game dataset IGDB API. She has successfully generated 1000 records. There are information about game name, genre, publish company, publish year, ageRating, theme, keywords and so on.These information can let us know the popular games' genre group to give some idea about market preferance, the information about ageRating group will give some idea about target customer group. The pubilic companies' information can suggest potential collaborators and competitors. The theme, keyworlds, story line and summary information can used to do text mining which will suggest some patterns.
#
# Project direction was new game develop.
#
#
# ### Octorber 9th 2020 wechart
#
# Christine share the game_infor_test.csv for group number to test.
#
#
#
# ### Octorber 10th 2020 wechart
#
# Discussion the how to join move data and game data.
#
# Chrsitine was dealing with target dataset define and main dataframe and sub dadta frame connection problem.
#
# ### Octorber 14th 2020 wechart
#
# Sarah has plot the world map by using game_companies data. Jay share the movie_star data. Whole group was working on the presentation.
#
#
# ### Octorber 15th 2020 group meeting
#
# Presentation. Well done! Though we still have some work has not achieved.
#
# ### October 20th 2020 Github
#
# Christine renew the IGDB codes and documents to Github.
# Jay push IMDB cods and documents to Github.
#
# ### October 22th 2020 Github
#
# Christine pushed the report to Github (path /Data422-project/Docs).
# Christine pushed the group_diary to Github (path /Data422-project/Docs).
